# %%
import tensorflow as tf
import os
import json

import tensorflow.keras.layers as layers
import matplotlib.pyplot as plt
import tensorflow.image as tfi
from keras.preprocessing.image import load_img, img_to_array

# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

import pennylane as qml
from pennylane import numpy as np

# %%
import cv2
from glob import glob

# %%
np.random.seed(42)

# %%
SIZE = 64
CHANNELS = 3
INPUT = (SIZE, SIZE, CHANNELS)

BATCH_SIZE = 64
EPOCHS = 10
NUM_SPLITS = 8

RUN = 'run3'

# %% [markdown]
# ## Data Work

# %%
def load_image(image, SIZE):
    # return np.expand_dims(cv2.imread(image)/255.0, axis=-1)
    return np.round(tfi.resize(img_to_array(load_img(image)),(SIZE, SIZE)))

def load_images(image_paths, SIZE, mask=False, trim=None):
    if trim is not None:
        image_paths = image_paths[:trim]
    
    image_paths = ['.' + path for path in image_paths]
    
    if mask:
        images = np.zeros(shape=(len(image_paths), SIZE, SIZE, 1))
    else:
        images = np.zeros(shape=(len(image_paths), SIZE, SIZE, CHANNELS))
    
    for i,image in enumerate(image_paths):
        img = tf.cast(load_image(image, SIZE), tf.float32) / 255.0
        if mask:
            images[i] = img[:,:,:1]
        else:
            img = img
            images[i] = img
    
    return images

# %%
def show_image(image, title=None, cmap=None, alpha=1):
    plt.imshow(image, cmap=cmap, alpha=alpha)
    if title is not None:
        plt.title(title)
    plt.axis('off')

def show_mask(image, mask, cmap=None, alpha=0.4):
    plt.imshow(image)
    plt.imshow(tf.squeeze(mask), cmap=cmap, alpha=alpha)
    plt.axis('off')

# %%
with open(f"../results-small/{RUN}/paths/train_img_paths.json", "r") as f:
    train_img_paths = json.load(f)

with open(f"../results-small/{RUN}/paths/val_img_paths.json", "r") as f:
    val_img_paths = json.load(f)

with open(f"../results-small/{RUN}/paths/test_img_paths.json", "r") as f:
    test_img_paths = json.load(f)

with open(f"../results-small/{RUN}/paths/train_mask_paths.json", "r") as f:
    train_mask_paths = json.load(f)

with open(f"../results-small/{RUN}/paths/val_mask_paths.json", "r") as f:
    val_mask_paths = json.load(f)

with open(f"../results-small/{RUN}/paths/test_mask_paths.json", "r") as f:
    test_mask_paths = json.load(f)

# %%
train_images = load_images(train_img_paths, SIZE)
train_masks = load_images(train_mask_paths, SIZE, mask=True)

# %%
len(train_images)
# Out:
# 607

# %%
val_images = load_images(val_img_paths, SIZE)
val_masks = load_images(val_mask_paths, SIZE, mask=True)

# %%
test_images = load_images(test_img_paths, SIZE)
test_masks = load_images(test_mask_paths, SIZE, mask=True)

# %%
# train_images[0].shape

# %%
# show_image(train_images[0])

# %%
# train_masks[0].shape

# %%
# show_mask(train_images[0], train_masks[0], cmap="gray", alpha=1)

# %%
# n_qubits = 4
# # Analytical simulator
# dev = qml.device("default.qubit", wires=n_qubits, shots=None)

# @qml.qnode(dev, diff_method="backprop")
# def qcnn(inputs, weight_0, weight_1):

#     # Input - Angle enoding
#     # for i in range(n_qubits):
#     #     qml.Hadamard(wires=i)
    
#     qml.AngleEmbedding(inputs*np.pi, wires=range(n_qubits), rotation="Y")
        
#     # PQC
#     # U1
#     qml.RX(weight_0[0], wires=0)
#     qml.RZ(weight_0[1], wires=1)
#     qml.CNOT(wires=[0, 1])

#     qml.RX(weight_0[0], wires=2)
#     qml.RZ(weight_0[1], wires=3)
#     qml.CNOT(wires=[2, 3])

#     qml.RX(weight_0[0], wires=1)
#     qml.RZ(weight_0[1], wires=2)
#     qml.CNOT(wires=[1, 2])

#     # V1
#     qml.CZ(wires=[0, 1])
#     qml.CZ(wires=[2, 3])

#     # U2
#     qml.RX(weight_1[0], wires=0)
#     qml.RY(weight_1[1], wires=2)
#     qml.CNOT(wires=[0, 2])

#     # V2
#     qml.CZ(wires=[0, 2])
  
#     return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
n_qubits = 4
# Analytical simulator
dev = qml.device("default.qubit", wires=n_qubits, shots=None)

@qml.qnode(dev, diff_method="backprop")
def qcnn1(inputs, weight_0, weight_1):

    # Input - Angle enoding
    # for i in range(n_qubits):
    #     qml.Hadamard(wires=i)
    
    qml.AngleEmbedding(inputs*np.pi, wires=range(n_qubits), rotation="Y")
        
    # PQC
    # U1
    qml.RX(weight_0[0], wires=0)
    qml.RZ(weight_0[1], wires=1)
    qml.CNOT(wires=[0, 1])

    qml.RX(weight_0[0], wires=2)
    qml.RZ(weight_0[1], wires=3)
    qml.CNOT(wires=[2, 3])

    qml.RX(weight_0[0], wires=1)
    qml.RZ(weight_0[1], wires=2)
    qml.CNOT(wires=[1, 2])

    # V1
    qml.CZ(wires=[0, 1])
    qml.CZ(wires=[2, 3])

    # U2
    qml.RX(weight_1[0], wires=0)
    qml.RY(weight_1[1], wires=2)
    qml.CNOT(wires=[0, 2])

    # V2
    qml.CZ(wires=[0, 2])
  
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
n_qubits = 4
# Analytical simulator
dev = qml.device("default.qubit", wires=n_qubits, shots=None)

@qml.qnode(dev, diff_method="backprop")
def qcnn2(inputs, weight_0, weight_1):

    # Input - Angle enoding
    for i in range(n_qubits):
        qml.Hadamard(wires=i)
    
    qml.AngleEmbedding(inputs*np.pi, wires=range(n_qubits), rotation="Z")
        
    # PQC
    # U1
    qml.RY(weight_0[0], wires=0)
    qml.RX(weight_0[1], wires=1)
    qml.CNOT(wires=[0, 1])

    qml.RY(weight_0[0], wires=2)
    qml.RX(weight_0[1], wires=3)
    qml.CNOT(wires=[2, 3])

    qml.RY(weight_0[0], wires=1)
    qml.RX(weight_0[1], wires=2)
    qml.CNOT(wires=[1, 2])

    # V1
    qml.CZ(wires=[0, 1])
    qml.CZ(wires=[2, 3])

    # U2
    qml.RZ(weight_1[0], wires=0)
    qml.RX(weight_1[1], wires=2)
    qml.CNOT(wires=[0, 2])

    # V2
    qml.CZ(wires=[0, 2])
  
    return [qml.expval(qml.PauliZ(wires=i)) for i in range(n_qubits)]

# %%
weight_shapes = {"weight_0": 2, "weight_1": 2}
qcnn_layer1 = qml.qnn.KerasLayer(qcnn1, weight_shapes, output_dim=n_qubits, name="qcnn1")
qcnn_layer2 = qml.qnn.KerasLayer(qcnn2, weight_shapes, output_dim=n_qubits, name="qcnn2")

# %%
def iou(y_true, y_pred):
    def f(y_true, y_pred, threshold=0.5):
        y_pred_b = tf.cast(y_pred > threshold, tf.float32)
        intersection = tf.reduce_sum(y_true*y_pred_b, axis=[1, 2, 3])
        union = tf.reduce_sum(y_true + y_pred_b, axis=[1, 2, 3]) - intersection

        iou = intersection/union
        return tf.reduce_mean(iou)
    
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

# %%
def build_unet_model(input_shape=(64, 64, 3)):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    c5 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c5)
    p5 = layers.MaxPooling2D((2, 2))(c5)

    # c6 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(p5)
    # c6 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c6)
    # p6 = layers.MaxPooling2D((2, 2))(c6)

    q_split = tf.split(p5, num_or_size_splits = NUM_SPLITS, axis=-1)

    q = []
    for i in range(NUM_SPLITS):
        fi = layers.Flatten()(q_split[i])
        q0 = qcnn_layer1(fi)
        q1 = qcnn_layer2(fi)
        map1 = layers.Reshape((2, 2, 1))(q0)
        map2 = layers.Reshape((2, 2, 1))(q1) 
        q_reshape = layers.concatenate([map1, map2], axis=-1)

        q.append(q_reshape)
    
    q_res = layers.concatenate(q, axis=-1, name="q-resultant")

    p_mod = layers.concatenate([p5, p5], axis=-1)
    q_res_add = layers.Add()([p_mod, q_res])

    # u1 = layers.Conv2DTranspose(16, (3, 3), strides=(2, 2), padding='same')(q_res_add)
    # u1 = layers.concatenate([u1, c6], axis=-1)
    # c7 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u1)
    # c7 = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c7)

    u2 = layers.Conv2DTranspose(8, (3, 3), strides=(2, 2), padding='same')(q_res_add)
    u2 = layers.concatenate([u2, c5], axis=-1)
    c8 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u2)
    c8 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c8)

    u3 = layers.Conv2DTranspose(8, (3, 3), strides=(2, 2), padding='same')(c8)
    u3 = layers.concatenate([u3, c4], axis=-1)
    c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u3)
    c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c9)

    u4 = layers.Conv2DTranspose(8, (3, 3), strides=(2, 2), padding='same')(c9)
    u4 = layers.concatenate([u4, c3], axis=-1)
    c10 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u4)
    c10 = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c10)

    u5 = layers.Conv2DTranspose(4, (3, 3), strides=(2, 2), padding='same')(c10)
    u5 = layers.concatenate([u5, c2], axis=-1)
    c11 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(u5)
    c11 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(c11)

    u6 = layers.Conv2DTranspose(4, (3, 3), strides=(2, 2), padding='same')(c11)
    u6 = layers.concatenate([u6, c1], axis=-1)
    c12 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(u6)
    c12 = layers.Conv2D(4, (3, 3), activation='relu', padding='same')(c12)

    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c12)

    model = tf.keras.Model(inputs, outputs)

    return model

# %%
model = build_unet_model(input_shape = INPUT)

optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer= optimizer, loss='binary_crossentropy', metrics=[iou])
# model.compile(optimizer= optimizer, loss='binary_crossentropy', metrics=tf.keras.metrics.BinaryIoU(name='iou'))

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]          0         []
#
#  conv2d (Conv2D)             (None, 64, 64, 4)            112       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 4)            148       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 32, 32, 4)            0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 4)            148       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 4)            148       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 16, 16, 4)            0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 8)            296       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 8)            584       ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 8)              0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 8)              584       ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 8)              584       ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 4, 4, 8)              0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 8)              584       ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 4, 4, 8)              584       ['conv2d_8[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 2, 2, 8)              0         ['conv2d_9[0][0]']
#  g2D)
#
#  tf.split (TFOpLambda)       [(None, 2, 2, 1),            0         ['max_pooling2d_4[0][0]']
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1),
#                               (None, 2, 2, 1)]
#
#  flatten (Flatten)           (None, 4)                    0         ['tf.split[0][0]']
#
#  flatten_1 (Flatten)         (None, 4)                    0         ['tf.split[0][1]']
#
#  flatten_2 (Flatten)         (None, 4)                    0         ['tf.split[0][2]']
#
#  flatten_3 (Flatten)         (None, 4)                    0         ['tf.split[0][3]']
#
#  flatten_4 (Flatten)         (None, 4)                    0         ['tf.split[0][4]']
#
#  flatten_5 (Flatten)         (None, 4)                    0         ['tf.split[0][5]']
#
#  flatten_6 (Flatten)         (None, 4)                    0         ['tf.split[0][6]']
#
#  flatten_7 (Flatten)         (None, 4)                    0         ['tf.split[0][7]']
#
#  qcnn1 (KerasLayer)          (None, 4)                    4         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]',
#                                                                      'flatten_2[0][0]',
#                                                                      'flatten_3[0][0]',
#                                                                      'flatten_4[0][0]',
#                                                                      'flatten_5[0][0]',
#                                                                      'flatten_6[0][0]',
#                                                                      'flatten_7[0][0]']
#
#  qcnn2 (KerasLayer)          (None, 4)                    4         ['flatten[0][0]',
#                                                                      'flatten_1[0][0]',
#                                                                      'flatten_2[0][0]',
#                                                                      'flatten_3[0][0]',
#                                                                      'flatten_4[0][0]',
#                                                                      'flatten_5[0][0]',
#                                                                      'flatten_6[0][0]',
#                                                                      'flatten_7[0][0]']
#
#  reshape (Reshape)           (None, 2, 2, 1)              0         ['qcnn1[0][0]']
#
#  reshape_1 (Reshape)         (None, 2, 2, 1)              0         ['qcnn2[0][0]']
#
#  reshape_2 (Reshape)         (None, 2, 2, 1)              0         ['qcnn1[1][0]']
#
#  reshape_3 (Reshape)         (None, 2, 2, 1)              0         ['qcnn2[1][0]']
#
#  reshape_4 (Reshape)         (None, 2, 2, 1)              0         ['qcnn1[2][0]']
#
#  reshape_5 (Reshape)         (None, 2, 2, 1)              0         ['qcnn2[2][0]']
#
#  reshape_6 (Reshape)         (None, 2, 2, 1)              0         ['qcnn1[3][0]']
#
#  reshape_7 (Reshape)         (None, 2, 2, 1)              0         ['qcnn2[3][0]']
#
#  reshape_8 (Reshape)         (None, 2, 2, 1)              0         ['qcnn1[4][0]']
#
#  reshape_9 (Reshape)         (None, 2, 2, 1)              0         ['qcnn2[4][0]']
#
#  reshape_10 (Reshape)        (None, 2, 2, 1)              0         ['qcnn1[5][0]']
#
#  reshape_11 (Reshape)        (None, 2, 2, 1)              0         ['qcnn2[5][0]']
#
#  reshape_12 (Reshape)        (None, 2, 2, 1)              0         ['qcnn1[6][0]']
#
#  reshape_13 (Reshape)        (None, 2, 2, 1)              0         ['qcnn2[6][0]']
#
#  reshape_14 (Reshape)        (None, 2, 2, 1)              0         ['qcnn1[7][0]']
#
#  reshape_15 (Reshape)        (None, 2, 2, 1)              0         ['qcnn2[7][0]']
#
#  concatenate (Concatenate)   (None, 2, 2, 2)              0         ['reshape[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  concatenate_1 (Concatenate  (None, 2, 2, 2)              0         ['reshape_2[0][0]',
#  )                                                                   'reshape_3[0][0]']
#
#  concatenate_2 (Concatenate  (None, 2, 2, 2)              0         ['reshape_4[0][0]',
#  )                                                                   'reshape_5[0][0]']
#
#  concatenate_3 (Concatenate  (None, 2, 2, 2)              0         ['reshape_6[0][0]',
#  )                                                                   'reshape_7[0][0]']
#
#  concatenate_4 (Concatenate  (None, 2, 2, 2)              0         ['reshape_8[0][0]',
#  )                                                                   'reshape_9[0][0]']
#
#  concatenate_5 (Concatenate  (None, 2, 2, 2)              0         ['reshape_10[0][0]',
#  )                                                                   'reshape_11[0][0]']
#
#  concatenate_6 (Concatenate  (None, 2, 2, 2)              0         ['reshape_12[0][0]',
#  )                                                                   'reshape_13[0][0]']
#
#  concatenate_7 (Concatenate  (None, 2, 2, 2)              0         ['reshape_14[0][0]',
#  )                                                                   'reshape_15[0][0]']
#
#  concatenate_8 (Concatenate  (None, 2, 2, 16)             0         ['max_pooling2d_4[0][0]',
#  )                                                                   'max_pooling2d_4[0][0]']
#
#  q-resultant (Concatenate)   (None, 2, 2, 16)             0         ['concatenate[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'concatenate_2[0][0]',
#                                                                      'concatenate_3[0][0]',
#                                                                      'concatenate_4[0][0]',
#                                                                      'concatenate_5[0][0]',
#                                                                      'concatenate_6[0][0]',
#                                                                      'concatenate_7[0][0]']
#
#  add (Add)                   (None, 2, 2, 16)             0         ['concatenate_8[0][0]',
#                                                                      'q-resultant[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 4, 4, 8)              1160      ['add[0][0]']
#  anspose)
#
#  concatenate_9 (Concatenate  (None, 4, 4, 16)             0         ['conv2d_transpose[0][0]',
#  )                                                                   'conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 8)              1160      ['concatenate_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 4, 4, 8)              584       ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 8, 8, 8)              584       ['conv2d_11[0][0]']
#  Transpose)
#
#  concatenate_10 (Concatenat  (None, 8, 8, 16)             0         ['conv2d_transpose_1[0][0]',
#  e)                                                                  'conv2d_7[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 8)              1160      ['concatenate_10[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 8)              584       ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 16, 16, 8)            584       ['conv2d_13[0][0]']
#  Transpose)
#
#  concatenate_11 (Concatenat  (None, 16, 16, 16)           0         ['conv2d_transpose_2[0][0]',
#  e)                                                                  'conv2d_5[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 8)            1160      ['concatenate_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 8)            584       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 32, 32, 4)            292       ['conv2d_15[0][0]']
#  Transpose)
#
#  concatenate_12 (Concatenat  (None, 32, 32, 8)            0         ['conv2d_transpose_3[0][0]',
#  e)                                                                  'conv2d_3[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 4)            292       ['concatenate_12[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 4)            148       ['conv2d_16[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 64, 64, 4)            148       ['conv2d_17[0][0]']
#  Transpose)
#
#  concatenate_13 (Concatenat  (None, 64, 64, 8)            0         ['conv2d_transpose_4[0][0]',
#  e)                                                                  'conv2d_1[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 4)            292       ['concatenate_13[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 4)            148       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 1)            5         ['conv2d_19[0][0]']
#
# ==================================================================================================
# Total params: 12665 (49.47 KB)
# Trainable params: 12665 (49.47 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# exp_vals = {i:[] for i in range(EPOCHS)}

# class IntermediateOutput(tf.keras.callbacks.Callback):
#     def on_epoch_end(self, epoch, logs={}):
#         func = tf.keras.backend.function([model.input], model.get_layer("q-resultant").output)
#         exp_val = func(train_images)
#         exp_vals[epoch].append(exp_val.astype(np.float32))

# %%
# Train the model
history = model.fit(
    x = train_images,
    y = train_masks,
    validation_data=(val_images, val_masks),
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    # callbacks = [IntermediateOutput()]
)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 15s 1s/step - loss: 0.6565 - iou: 0.0298 - val_loss: 0.6219 - val_iou: 6.5629e-06
# Epoch 2/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.5983 - iou: 7.9949e-06 - val_loss: 0.5946 - val_iou: 0.0000e+00
# Epoch 3/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.5736 - iou: 0.0000e+00 - val_loss: 0.5738 - val_iou: 0.0000e+00
# Epoch 4/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.5425 - iou: 9.3325e-07 - val_loss: 0.5330 - val_iou: 1.5209e-04
# Epoch 5/10
# 10/10 [==============================] - 16s 2s/step - loss: 0.4932 - iou: 0.0314 - val_loss: 0.4627 - val_iou: 0.0895
# Epoch 6/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.4038 - iou: 0.4630 - val_loss: 0.3648 - val_iou: 0.7572
# Epoch 7/10
# 10/10 [==============================] - 15s 1s/step - loss: 0.3249 - iou: 0.7945 - val_loss: 0.3218 - val_iou: 0.7990
# Epoch 8/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.2449 - iou: 0.8152 - val_loss: 0.1950 - val_iou: 0.8506
# Epoch 9/10
# 10/10 [==============================] - 14s 1s/step - loss: 0.1766 - iou: 0.8373 - val_loss: 0.1576 - val_iou: 0.8696
# Epoch 10/10
# 10/10 [==============================] - 15s 2s/step - loss: 0.1529 - iou: 0.8539 - val_loss: 0.1719 - val_iou: 0.8671

# %%
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.xlabel("Epochs")
plt.ylabel("BCE Loss")
plt.title("Loss plot")
plt.xticks(range(0, EPOCHS+1, 2))
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(history.history["iou"], label="IoU")
plt.plot(history.history["val_iou"], label="Val IoU")
plt.xlabel("Epochs")
plt.ylabel("IoU")
plt.title("IoU plot")
plt.xticks(range(0, EPOCHS+1, 2))
plt.legend()
plt.grid(True)
plt.show()

# %%
test_loss, test_iou = model.evaluate(x = test_images, y = test_masks)
print(f"Test Loss: {test_loss}")
print(f"Test iou: {test_iou}")
# Out:
# 3/3 [==============================] - 2s 556ms/step - loss: 0.1686 - iou: 0.8549
# Test Loss: 0.16861224174499512
# Test iou: 0.8548603057861328

# %%
# Function to visualize a batch of images, ground truth masks, and predictions
def visualize_batch(images, masks, predictions, num_images=5):
    fig, axs = plt.subplots(num_images, 3, figsize=(6, num_images * 3))
    
    for i in range(num_images):
        axs[i, 0].imshow(images[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axs[i, 0].set_title(f'Image {i+1}')
        axs[i, 0].axis('off')
        
        axs[i, 1].imshow(masks[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axs[i, 1].set_title(f'Ground Truth Mask {i+1}')
        axs[i, 1].axis('off')
        
        axs[i, 2].imshow(predictions[i].squeeze(), cmap="gray", vmin=0, vmax=1)
        axs[i, 2].set_title(f'Predicted Mask {i+1}')
        axs[i, 2].axis('off')
    
    plt.tight_layout()
    plt.show()

# Function to get predictions and visualize a batch
def visualize_test_dataset(model, dataset, num_images=5):
    images, masks = dataset
    predictions = model.predict(images)
    visualize_batch(images, masks, predictions, num_images=num_images)

# %%
predictions = model.predict(test_images)
predictions.shape
# Out:
# 3/3 [==============================] - 2s 549ms/step
# (76, 64, 64, 1)

# %%
np.max(predictions[0])
# Out:
# 0.9902026

# %%
len(test_images), len(test_masks)
# Out:
# (76, 76)

# %%
sample_iou = iou(test_masks, predictions)
print(sample_iou)
print(np.mean(sample_iou))
print(tf.reduce_mean(sample_iou))
# Out:
# tf.Tensor(0.8527082, shape=(), dtype=float32)
# 0.8527082
# tf.Tensor(0.8527082, shape=(), dtype=float32)

# %%
visualize_test_dataset(model, (test_images, test_masks), num_images=10)
# Out:
# 3/3 [==============================] - 2s 547ms/step

# %%
# exp_vals_processed = np.array([np.concatenate(exp_vals[i], axis=0).numpy() for i in range(EPOCHS)])
# exp_vals_processed = exp_vals_processed.reshape(EPOCHS, len(train_images), -1, NUM_SPLITS)
# exp_vals_processed.shape

# %%
# fig, ax = plt.subplots(NUM_SPLITS, 1, sharex=True, sharey=True, figsize=(8, 4*NUM_SPLITS))

# for e in range(NUM_SPLITS):
#     for i in range(n_qubits):
#         ax[e].plot(exp_vals_processed[:, 0, i][...,e], label="q{}".format(i))
#         ax[e].grid(True)
#         ax[e].legend()
#         ax[e].set_title("Exp val - split {}".format(e))

# plt.show()

# %%
np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/predictions.npy", predictions)

# %%
# np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/exp_vals.npy", exp_vals_processed)

# %%
model.save_weights(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/weights/trained_weights.h5")

# %%
np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/train_loss.npy", history.history["loss"])
np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/val_loss.npy", history.history["val_loss"])

np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/train_iou.npy", history.history["iou"])
np.save(f"../results-tiny/{RUN}/qcnn_res_tiny4-2/val_iou.npy", history.history["val_iou"])

# %%
with open("../results-tiny/consolidated.txt", "a") as f:
    f.writelines([f'{RUN}', '\tQCNN-tiny4-2', '\t\ttest_loss: {}'.format(test_loss), '\t\ttest_iou: {}\n\n'.format(test_iou)])
